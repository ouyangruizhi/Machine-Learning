# %% [markdown]
# # 统计学习导论第九次作业
# 作业任务：基于用户的协同过滤和基于物品的协同过滤
# surprise库都能实现，伟大，但基于物品的算的太慢了

# %% [markdown]
# 姓名：欧阳瑞志、班级：统计22、学号：220403102

# %% [markdown]
# ## 一、数据导入
# ### 数据来源
# Grouplens提供的数据集MovieLens
# ### 主题
# 推荐算法--协同过滤
# ### 数据地址
# https://grouplens.org/datasets/movielens/1m/

# %%
####--------------------------------统计学习导论第九次作业（协同过滤）--------------------------------####

from surprise import Dataset
from surprise import Reader
from surprise import KNNBasic, KNNWithMeans, KNNWithZScore, KNNBaseline
import numpy as np
import time

# --------------------------------1、数据导入--------------------------------#
# Grouplens提供的数据集MovieLens 
# 主题：推荐算法--协同过滤
# 地址：https://grouplens.org/datasets/movielens/1m/

data = Dataset.load_builtin('ml-1m')

reader = Reader(line_format='user item rating timestamp', sep='\t')
trainset = data.build_full_trainset()

num_users = trainset.n_users
num_items = trainset.n_items
all_ratings = trainset.all_ratings()

print(f"Number of users: {num_users}")
print(f"Number of items: {num_items}")
print(f"All ratings: {all_ratings}")

first_10_ratings = list(all_ratings)[:10]
print(first_10_ratings)
# Out:
# Number of users: 6040
# Number of items: 3706
# All ratings: <generator object Trainset.all_ratings at 0x110e152e0>
# [(0, 0, 5.0), (0, 1, 3.0), (0, 2, 3.0), (0, 3, 4.0), (0, 4, 5.0), (0, 5, 3.0), (0, 6, 5.0), (0, 7, 5.0), (0, 8, 4.0), (0, 9, 4.0)]

# %% [markdown]
# ## 二、基于用户的协同过滤
# ### 2.1 调参
# __相似度__：'cosine'，余弦相似度；'pearson'，皮尔逊相似系数；'msd'，均方差；'pearson_baseline'，基于baseline的pearson相似系数
# __k值__：考虑从2到500，这里仅展示最后一步调整k值

# %%
# --------------------------------2、基于用户的协同过滤进行推荐--------------------------------#
reader = Reader(rating_scale=(1, 5))

## 调参
start_time = time.time()
# 定义不同的相似度计算方法和k值的组合进行尝试
sim_names = ['cosine', 'pearson', 'msd', 'pearson_baseline']  # 余弦相似度、皮尔逊相关系数、均方差
k_values = [5, 10, 20, 30, 40, 50]

best_mape = float('inf')
best_params = None

# MAPE函数
def mape(true_ratings, predicted_ratings):
    errors = []
    for true_r, pred_r in zip(true_ratings, predicted_ratings):
        if true_r!= 0:
            error = abs((true_r - pred_r) / true_r)
            errors.append(error)
    return np.mean(errors) if errors else 0

# 遍历不同的参数组合
for sim_name in sim_names:
    for k in k_values:
        reader = Reader(rating_scale=(1, 5))

        # 构建基于用户的协同过滤推荐模型
        sim_options = {'name': sim_name, 'user_based': True}  ## user_based设为True为基于用户的协同过滤
        model = KNNBasic(k=k, sim_options=sim_options)  ## 算法也可以调：KNNBasic, KNNWithMeans, KNNWithZScore, KNNBaseline
        model.fit(trainset)

        true_ratings = []
        predicted_ratings = []

        # 计算所有用户的真实评分与预测评分
        for user_id in range(trainset.n_users):
            for item_id, rating in trainset.ur[user_id]:
                prediction = model.predict(user_id, item_id).est
                true_ratings.append(rating)
                predicted_ratings.append(prediction)

        # 计算MAPE
        current_mape = mape(true_ratings, predicted_ratings)
        print(f"使用 {sim_name} 相似度，k={k} 时的 MAPE: {current_mape}")

        # 更新最佳参数组合和最小的MAPE值
        if current_mape < best_mape:
            best_mape = current_mape
            best_params = (sim_name, k)

print(f"最佳参数组合为：相似度计算方法 '{best_params[0]}'，k值 {best_params[1]}，对应的最小MAPE为 {best_mape}")

end_time = time.time()
print(f"基于用户的协同过滤调参耗时: {end_time - start_time} 秒")

print('########调参结束########')
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# 使用 cosine 相似度，k=5 时的 MAPE: 0.38133226143416266
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# 使用 cosine 相似度，k=10 时的 MAPE: 0.38133226143416266
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# 使用 cosine 相似度，k=20 时的 MAPE: 0.38133226143416266
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# 使用 cosine 相似度，k=30 时的 MAPE: 0.38133226143416266
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# 使用 cosine 相似度，k=40 时的 MAPE: 0.38133226143416266
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# 使用 cosine 相似度，k=50 时的 MAPE: 0.38133226143416266
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# 使用 pearson 相似度，k=5 时的 MAPE: 0.38133226143416266
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# 使用 pearson 相似度，k=10 时的 MAPE: 0.38133226143416266
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# 使用 pearson 相似度，k=20 时的 MAPE: 0.38133226143416266
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# 使用 pearson 相似度，k=30 时的 MAPE: 0.38133226143416266
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# 使用 pearson 相似度，k=40 时的 MAPE: 0.38133226143416266
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# 使用 pearson 相似度，k=50 时的 MAPE: 0.38133226143416266
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# 使用 msd 相似度，k=5 时的 MAPE: 0.38133226143416266
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# 使用 msd 相似度，k=10 时的 MAPE: 0.38133226143416266
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# 使用 msd 相似度，k=20 时的 MAPE: 0.38133226143416266
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# 使用 msd 相似度，k=30 时的 MAPE: 0.38133226143416266
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# 使用 msd 相似度，k=40 时的 MAPE: 0.38133226143416266
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# 使用 msd 相似度，k=50 时的 MAPE: 0.38133226143416266
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# 使用 pearson_baseline 相似度，k=5 时的 MAPE: 0.38133226143416266
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# 使用 pearson_baseline 相似度，k=10 时的 MAPE: 0.38133226143416266
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# 使用 pearson_baseline 相似度，k=20 时的 MAPE: 0.38133226143416266
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# 使用 pearson_baseline 相似度，k=30 时的 MAPE: 0.38133226143416266
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# 使用 pearson_baseline 相似度，k=40 时的 MAPE: 0.38133226143416266
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# 使用 pearson_baseline 相似度，k=50 时的 MAPE: 0.38133226143416266
# 最佳参数组合为：相似度计算方法 'cosine'，k值 5，对应的最小MAPE为 0.38133226143416266
# 基于用户的协同过滤调参耗时: 431.08674716949463 秒
# ########调参结束########

# %% [markdown]
# ### 2.2 KNNBasic实现基于用户的协同分析
# 方法考虑了： KNNBasic, KNNWithMeans, KNNWithZScore, KNNBaseline，对比MAPE选择KNNBasic

# %%
## 最佳参数进模型
sim_options = {'name': 'cosine', 'user_based': True}
model = KNNBasic(k=5, sim_options=sim_options)
model.fit(trainset)

# 推荐用户ID范围设为1到10
for target_user_id in range(1, 11):
    # 获取目标用户已经看过的电影
    watched_movies_by_target_user = trainset.ur[target_user_id]
    watched_movie_ids = [movie_id for (movie_id, _) in watched_movies_by_target_user]

    recommendations = []

    for other_user_id in range(trainset.n_users):
        if other_user_id!= target_user_id:
            similarity = model.sim[target_user_id][other_user_id]
            if similarity > 0:  # 只考虑有正相似度的用户，表示相似用户
                other_user_watched_movies = trainset.ur[other_user_id]
                for movie_id, _ in other_user_watched_movies:
                    if movie_id not in watched_movie_ids:
                        # 预测目标用户对该电影的评分
                        prediction = model.predict(target_user_id, movie_id).est
                        recommendations.append((movie_id, prediction))

    final_recommendations = []
    # 去重
    added_movie_ids = set()
    # 先按照评分从高到低排序
    sorted_recommendations = sorted(recommendations, key=lambda x: x[1], reverse=True)
    # 遍历排序后的推荐结果，取评分排名前十的不同电影
    for movie_id, score in sorted_recommendations:
        if len(final_recommendations) < 10 and movie_id not in added_movie_ids:
            final_recommendations.append((movie_id, score))
            added_movie_ids.add(movie_id)

    print(f"为用户 {target_user_id} 推荐的电影（电影ID，预测评分）：")
    for movie_id, score in final_recommendations:
        print(f"电影ID: {movie_id}, 预测评分: {score}")
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# 为用户 1 推荐的电影（电影ID，预测评分）：
# 电影ID: 1, 预测评分: 3.581564453029317
# 电影ID: 2, 预测评分: 3.581564453029317
# 电影ID: 3, 预测评分: 3.581564453029317
# 电影ID: 4, 预测评分: 3.581564453029317
# 电影ID: 5, 预测评分: 3.581564453029317
# 电影ID: 6, 预测评分: 3.581564453029317
# 电影ID: 7, 预测评分: 3.581564453029317
# 电影ID: 8, 预测评分: 3.581564453029317
# 电影ID: 9, 预测评分: 3.581564453029317
# 电影ID: 10, 预测评分: 3.581564453029317
# 为用户 2 推荐的电影（电影ID，预测评分）：
# 电影ID: 0, 预测评分: 3.581564453029317
# 电影ID: 1, 预测评分: 3.581564453029317
# 电影ID: 2, 预测评分: 3.581564453029317
# 电影ID: 3, 预测评分: 3.581564453029317
# 电影ID: 6, 预测评分: 3.581564453029317
# 电影ID: 7, 预测评分: 3.581564453029317
# 电影ID: 8, 预测评分: 3.581564453029317
# 电影ID: 9, 预测评分: 3.581564453029317
# 电影ID: 10, 预测评分: 3.581564453029317
# 电影ID: 11, 预测评分: 3.581564453029317
# 为用户 3 推荐的电影（电影ID，预测评分）：
# 电影ID: 0, 预测评分: 3.581564453029317
# 电影ID: 1, 预测评分: 3.581564453029317
# 电影ID: 2, 预测评分: 3.581564453029317
# 电影ID: 3, 预测评分: 3.581564453029317
# 电影ID: 4, 预测评分: 3.581564453029317
# 电影ID: 5, 预测评分: 3.581564453029317
# 电影ID: 6, 预测评分: 3.581564453029317
# 电影ID: 7, 预测评分: 3.581564453029317
# 电影ID: 8, 预测评分: 3.581564453029317
# 电影ID: 9, 预测评分: 3.581564453029317
# 为用户 4 推荐的电影（电影ID，预测评分）：
# 电影ID: 0, 预测评分: 3.581564453029317
# 电影ID: 1, 预测评分: 3.581564453029317
# 电影ID: 2, 预测评分: 3.581564453029317
# 电影ID: 5, 预测评分: 3.581564453029317
# 电影ID: 6, 预测评分: 3.581564453029317
# 电影ID: 7, 预测评分: 3.581564453029317
# 电影ID: 8, 预测评分: 3.581564453029317
# 电影ID: 10, 预测评分: 3.581564453029317
# 电影ID: 11, 预测评分: 3.581564453029317
# 电影ID: 12, 预测评分: 3.581564453029317
# 为用户 5 推荐的电影（电影ID，预测评分）：
# 电影ID: 0, 预测评分: 3.581564453029317
# 电影ID: 1, 预测评分: 3.581564453029317
# 电影ID: 4, 预测评分: 3.581564453029317
# 电影ID: 5, 预测评分: 3.581564453029317
# 电影ID: 6, 预测评分: 3.581564453029317
# 电影ID: 7, 预测评分: 3.581564453029317
# 电影ID: 8, 预测评分: 3.581564453029317
# 电影ID: 9, 预测评分: 3.581564453029317
# 电影ID: 11, 预测评分: 3.581564453029317
# 电影ID: 12, 预测评分: 3.581564453029317
# 为用户 6 推荐的电影（电影ID，预测评分）：
# 电影ID: 0, 预测评分: 3.581564453029317
# 电影ID: 1, 预测评分: 3.581564453029317
# 电影ID: 2, 预测评分: 3.581564453029317
# 电影ID: 3, 预测评分: 3.581564453029317
# 电影ID: 4, 预测评分: 3.581564453029317
# 电影ID: 5, 预测评分: 3.581564453029317
# 电影ID: 6, 预测评分: 3.581564453029317
# 电影ID: 7, 预测评分: 3.581564453029317
# 电影ID: 8, 预测评分: 3.581564453029317
# 电影ID: 9, 预测评分: 3.581564453029317
# 为用户 7 推荐的电影（电影ID，预测评分）：
# 电影ID: 0, 预测评分: 3.581564453029317
# 电影ID: 1, 预测评分: 3.581564453029317
# 电影ID: 2, 预测评分: 3.581564453029317
# 电影ID: 3, 预测评分: 3.581564453029317
# 电影ID: 4, 预测评分: 3.581564453029317
# 电影ID: 5, 预测评分: 3.581564453029317
# 电影ID: 6, 预测评分: 3.581564453029317
# 电影ID: 7, 预测评分: 3.581564453029317
# 电影ID: 8, 预测评分: 3.581564453029317
# 电影ID: 9, 预测评分: 3.581564453029317
# 为用户 8 推荐的电影（电影ID，预测评分）：
# 电影ID: 0, 预测评分: 3.581564453029317
# 电影ID: 1, 预测评分: 3.581564453029317
# 电影ID: 2, 预测评分: 3.581564453029317
# 电影ID: 5, 预测评分: 3.581564453029317
# 电影ID: 6, 预测评分: 3.581564453029317
# 电影ID: 7, 预测评分: 3.581564453029317
# 电影ID: 8, 预测评分: 3.581564453029317
# 电影ID: 9, 预测评分: 3.581564453029317
# 电影ID: 10, 预测评分: 3.581564453029317
# 电影ID: 11, 预测评分: 3.581564453029317
# 为用户 9 推荐的电影（电影ID，预测评分）：
# 电影ID: 0, 预测评分: 3.581564453029317
# 电影ID: 1, 预测评分: 3.581564453029317
# 电影ID: 16, 预测评分: 3.581564453029317
# 电影ID: 18, 预测评分: 3.581564453029317
# 电影ID: 24, 预测评分: 3.581564453029317
# 电影ID: 28, 预测评分: 3.581564453029317
# 电影ID: 31, 预测评分: 3.581564453029317
# 电影ID: 34, 预测评分: 3.581564453029317
# 电影ID: 35, 预测评分: 3.581564453029317
# 电影ID: 36, 预测评分: 3.581564453029317
# 为用户 10 推荐的电影（电影ID，预测评分）：
# 电影ID: 0, 预测评分: 3.581564453029317
# 电影ID: 1, 预测评分: 3.581564453029317
# 电影ID: 2, 预测评分: 3.581564453029317
# 电影ID: 3, 预测评分: 3.581564453029317
# 电影ID: 6, 预测评分: 3.581564453029317
# 电影ID: 8, 预测评分: 3.581564453029317
# 电影ID: 9, 预测评分: 3.581564453029317
# 电影ID: 10, 预测评分: 3.581564453029317
# 电影ID: 11, 预测评分: 3.581564453029317
# 电影ID: 12, 预测评分: 3.581564453029317

# %% [markdown]
# ## 三、基于物品的协同分析
# ### 3.1 调参
# __相似度__：'cosine'，余弦相似度；'pearson'，皮尔逊相似系数；'msd'，均方差；'pearson_baseline'，基于baseline的pearson相似系数
# __k值__：考虑从2到500，这里仅展示最后一步调整k值

# %%
# --------------------------------3、基于物品的协同过滤进行推荐--------------------------------#

## 调参
start_time = time.time()

sim_names_item = ['cosine', 'pearson', 'msd', 'pearson_baseline']  # 余弦相似度、皮尔逊相关系数、均方差
k_values_item = [5, 10, 20, 30, 40, 50]

best_mape_item = float('inf')
best_params_item = None

for sim_name in sim_names_item:
    for k in k_values_item:

        # 构建基于物品的协同过滤推荐模型
        sim_options = {'name': sim_name, 'user_based': False}  # 设置user_based为False，实现基于物品的协同过滤
        model = KNNWithZScore(k=k, sim_options=sim_options)
        model.fit(trainset)

        true_ratings = []
        predicted_ratings = []

        # 计算真实评分与预测评分
        for user_id in range(trainset.n_users):
            for item_id, rating in trainset.ur[user_id]:
                prediction = model.predict(user_id, item_id).est
                true_ratings.append(rating)
                predicted_ratings.append(prediction)

        # 计算MAPE
        current_mape = mape(true_ratings, predicted_ratings)
        print(f"使用 {sim_name} 相似度，k={k} 时的 MAPE（基于物品的协同过滤）: {current_mape}")

        # 更新最佳参数组合和最小的MAPE值（基于物品的协同过滤）
        if current_mape < best_mape_item:
            best_mape_item = current_mape
            best_params_item = (sim_name, k)

print(f"基于物品的协同过滤最佳参数组合为：相似度计算方法 '{best_params_item[0]}'，k值 {best_params_item[1]}，对应的最小MAPE为 {best_mape_item}")

end_time = time.time()
print(f"基于物品的协同过滤调参耗时: {end_time - start_time} 秒")

print('########调参结束########')
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# 使用 cosine 相似度，k=5 时的 MAPE（基于物品的协同过滤）: 0.38133226143416266
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# 使用 cosine 相似度，k=10 时的 MAPE（基于物品的协同过滤）: 0.38133226143416266
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# 使用 cosine 相似度，k=20 时的 MAPE（基于物品的协同过滤）: 0.38133226143416266
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# 使用 cosine 相似度，k=30 时的 MAPE（基于物品的协同过滤）: 0.38133226143416266
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# 使用 cosine 相似度，k=40 时的 MAPE（基于物品的协同过滤）: 0.38133226143416266
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# 使用 cosine 相似度，k=50 时的 MAPE（基于物品的协同过滤）: 0.38133226143416266
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# 使用 pearson 相似度，k=5 时的 MAPE（基于物品的协同过滤）: 0.38133226143416266
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# 使用 pearson 相似度，k=10 时的 MAPE（基于物品的协同过滤）: 0.38133226143416266
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# 使用 pearson 相似度，k=20 时的 MAPE（基于物品的协同过滤）: 0.38133226143416266
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# 使用 pearson 相似度，k=30 时的 MAPE（基于物品的协同过滤）: 0.38133226143416266
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# 使用 pearson 相似度，k=40 时的 MAPE（基于物品的协同过滤）: 0.38133226143416266
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# 使用 pearson 相似度，k=50 时的 MAPE（基于物品的协同过滤）: 0.38133226143416266
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# 使用 msd 相似度，k=5 时的 MAPE（基于物品的协同过滤）: 0.38133226143416266
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# 使用 msd 相似度，k=10 时的 MAPE（基于物品的协同过滤）: 0.38133226143416266
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# 使用 msd 相似度，k=20 时的 MAPE（基于物品的协同过滤）: 0.38133226143416266
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# 使用 msd 相似度，k=30 时的 MAPE（基于物品的协同过滤）: 0.38133226143416266
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# 使用 msd 相似度，k=40 时的 MAPE（基于物品的协同过滤）: 0.38133226143416266
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# 使用 msd 相似度，k=50 时的 MAPE（基于物品的协同过滤）: 0.38133226143416266
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# 使用 pearson_baseline 相似度，k=5 时的 MAPE（基于物品的协同过滤）: 0.38133226143416266
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# 使用 pearson_baseline 相似度，k=10 时的 MAPE（基于物品的协同过滤）: 0.38133226143416266
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# 使用 pearson_baseline 相似度，k=20 时的 MAPE（基于物品的协同过滤）: 0.38133226143416266
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# 使用 pearson_baseline 相似度，k=30 时的 MAPE（基于物品的协同过滤）: 0.38133226143416266
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# 使用 pearson_baseline 相似度，k=40 时的 MAPE（基于物品的协同过滤）: 0.38133226143416266
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# 使用 pearson_baseline 相似度，k=50 时的 MAPE（基于物品的协同过滤）: 0.38133226143416266
# 基于物品的协同过滤最佳参数组合为：相似度计算方法 'cosine'，k值 5，对应的最小MAPE为 0.38133226143416266
# 基于物品的协同过滤调参耗时: 207.76585292816162 秒
# ########调参结束########

# %% [markdown]
# ### 3.2 KNNWithZScore实现基于物品的协同分析
# 方法考虑了： KNNBasic, KNNWithMeans, KNNWithZScore, KNNBaseline，对比MAPE选择KNNBasic
# 这一步由于要便利所有ID，这一步需要3h
# 为了观测计算进度，输出了每次计算结果，共3700+条

# %%
# 最佳参数进模型
sim_options_item = {'name': best_params_item[0], 'user_based': False, 'k': best_params_item[1]}
model_item = KNNWithZScore(sim_options=sim_options_item)
model_item.fit(trainset)

start_time = time.time()

for target_user_id in [1]:
    watched_items_ratings = []
    for user_id, item_id, rating in trainset.all_ratings():
        if item_id in [movie_id for (movie_id, _) in trainset.ur[target_user_id]]:
            watched_items_ratings.append((item_id, rating))

    watched_movie_ids_item = [movie_id for movie_id, _ in watched_items_ratings]

    recommendations_item = []

    for item_id in range(trainset.n_items):
        if item_id not in watched_movie_ids_item:
            similarity = model_item.sim[item_id]
            print(f"Item ID: {item_id}, Similarity values: {similarity}")
            for other_item_id, similarity_value in enumerate(similarity):
                if other_item_id in watched_movie_ids_item and similarity_value > 0:

                    prediction = model_item.predict(target_user_id, item_id).est
                    recommendations_item.append((item_id, prediction))

    final_recommendations_item = []
    added_movie_ids_item = set()
    # 先按照评分从高到低排序
    sorted_recommendations_item = sorted(recommendations_item, key=lambda x: x[1], reverse=True)
    # 遍历排序后的推荐结果，取评分排名前十的不同电影
    for movie_id, score in sorted_recommendations_item:
        if len(final_recommendations_item) < 10 and movie_id not in added_movie_ids_item:
            final_recommendations_item.append((movie_id, score))
            added_movie_ids_item.add(movie_id)

    print(f"基于物品的协同过滤为用户 {target_user_id} 推荐的电影（电影ID，预测评分）：")
    for movie_id, score in final_recommendations_item:
        print(f"电影ID: {movie_id}, 预测评分: {score}")

end_time = time.time()
print(f"基于物品的协同过滤最佳参数计算耗时: {end_time - start_time} 秒")
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Item ID: 1, Similarity values: [0.95556011 1.         0.93827998 ... 0.         0.         0.        ]
# Item ID: 2, Similarity values: [0.96639164 0.93827998 1.         ... 0.         0.         0.        ]
# Item ID: 3, Similarity values: [0.96067846 0.93029121 0.96632659 ... 0.         0.         0.        ]
# Item ID: 4, Similarity values: [0.96369964 0.95890738 0.96621826 ... 0.         0.         0.        ]
# Item ID: 5, Similarity values: [0.96810869 0.94726375 0.96514344 ... 0.         1.         1.        ]
# Item ID: 6, Similarity values: [0.96678531 0.94502466 0.95972701 ... 0.         0.         0.        ]
# Item ID: 7, Similarity values: [0.96782115 0.93832889 0.96083452 ... 0.         0.         0.        ]
# Item ID: 8, Similarity values: [0.96171441 0.94813431 0.96777411 ... 0.         0.         0.        ]
# Item ID: 9, Similarity values: [0.96931821 0.94987369 0.97296714 ... 0.         1.         0.        ]
# Item ID: 10, Similarity values: [0.95382204 0.93636164 0.96408785 ... 0.         1.         0.        ]
# Item ID: 11, Similarity values: [0.94667872 0.92918985 0.97008075 ... 0.         0.         0.        ]
# Item ID: 12, Similarity values: [0.95982012 0.93365215 0.9669209  ... 0.         0.         0.        ]
# Item ID: 13, Similarity values: [0.96521196 0.94572911 0.9626328  ... 0.         0.         0.        ]
# Item ID: 14, Similarity values: [0.94914191 0.92909475 0.96960611 ... 0.         0.         0.        ]
# Item ID: 15, Similarity values: [0.95999447 0.94170664 0.94884728 ... 0.         1.         0.        ]
# Item ID: 16, Similarity values: [0.94621562 0.95675362 0.96521387 ... 0.         1.         0.        ]
# Item ID: 17, Similarity values: [0.9573465  0.95416566 0.95984862 ... 0.         1.         0.        ]
# Item ID: 19, Similarity values: [0.96621697 0.93936685 0.96725521 ... 0.         0.         0.        ]
# Item ID: 21, Similarity values: [0.97382622 0.96316806 0.97124477 ... 0.         0.         1.        ]
# Item ID: 22, Similarity values: [0.96352651 0.94419287 0.96420116 ... 0.         1.         0.        ]
# Item ID: 23, Similarity values: [0.97687593 0.94986282 0.97248684 ... 0.         0.         0.        ]
# Item ID: 24, Similarity values: [0.94482817 0.93456162 0.93103898 ... 0.         0.         0.        ]
# Item ID: 25, Similarity values: [0.92119176 0.91357757 0.93736886 ... 0.         0.         0.        ]
# Item ID: 26, Similarity values: [0.96605468 0.9444211  0.96828793 ... 0.         1.         0.        ]
# Item ID: 27, Similarity values: [0.93717643 0.9069583  0.94709736 ... 1.         0.         0.        ]
# Item ID: 28, Similarity values: [0.97354158 0.94222856 0.96658507 ... 0.         0.         0.        ]
# Item ID: 29, Similarity values: [0.9811913  0.96587532 0.97456745 ... 0.         0.         1.        ]
# Item ID: 30, Similarity values: [0.95737014 0.9527833  0.95606343 ... 1.         0.         0.        ]
# Item ID: 31, Similarity values: [0.95621984 0.9324425  0.95299339 ... 0.         0.         0.        ]
# Item ID: 32, Similarity values: [0.9321965  0.93649718 0.94978537 ... 0.         1.         0.        ]
# Item ID: 33, Similarity values: [0.95839444 0.94544774 0.96535676 ... 1.         1.         0.        ]
# Item ID: 34, Similarity values: [0.95736313 0.93587705 0.96999963 ... 0.         1.         0.        ]
# Item ID: 35, Similarity values: [0.94078171 0.94541092 0.9487585  ... 0.         1.         0.        ]
# Item ID: 36, Similarity values: [0.93940837 0.93558658 0.95586171 ... 0.         0.         0.        ]
# Item ID: 37, Similarity values: [0.95681465 0.93637148 0.97120284 ... 0.         1.         0.        ]
# Item ID: 38, Similarity values: [0.97150685 0.95011221 0.96574297 ... 0.         1.         1.        ]
# Item ID: 39, Similarity values: [0.96862023 0.9433585  0.97018349 ... 1.         0.         0.        ]
# Item ID: 40, Similarity values: [0.96514975 0.9526873  0.96595639 ... 1.         0.         1.        ]
# Item ID: 41, Similarity values: [0.97450335 0.94667788 0.97071546 ... 0.         0.         0.        ]
# Item ID: 43, Similarity values: [0.97168911 0.96097668 0.95633145 ... 0.         1.         1.        ]
# Item ID: 44, Similarity values: [0.97085279 0.95504115 0.96837254 ... 0.         1.         1.        ]
# Item ID: 45, Similarity values: [0.95566926 0.93789867 0.9688524  ... 0.         1.         0.        ]
# Item ID: 46, Similarity values: [0.96323123 0.94997543 0.96239897 ... 0.         0.         0.        ]
# Item ID: 49, Similarity values: [0.96741035 0.96018291 0.96646039 ... 0.         1.         0.        ]
# Item ID: 50, Similarity values: [0.96727677 0.95377271 0.96120816 ... 0.         0.         0.        ]
# Item ID: 51, Similarity values: [0.97445675 0.95584757 0.95885189 ... 1.         0.         1.        ]
# Item ID: 175, Similarity values: [0.96384811 0.92937001 0.94545647 ... 0.         0.         0.        ]
# Item ID: 176, Similarity values: [0.96358173 0.95367716 0.96592585 ... 0.         0.         1.        ]
# Item ID: 177, Similarity values: [0.96639794 0.94518031 0.94429417 ... 0.         0.         0.        ]
# Item ID: 178, Similarity values: [0.94777568 0.93152862 0.9358891  ... 0.         0.         0.        ]
# Item ID: 179, Similarity values: [0.9314014  0.89303245 0.91947067 ... 1.         0.         0.        ]
# Item ID: 180, Similarity values: [0.93685683 0.91104991 0.92857752 ... 0.         0.         1.        ]
# Item ID: 181, Similarity values: [0.89656884 0.87012949 0.8885382  ... 0.         0.         0.        ]
# Item ID: 182, Similarity values: [0.94307525 0.91927816 0.94477413 ... 0.         0.         0.        ]
# Item ID: 183, Similarity values: [0.96594898 0.95009643 0.95886588 ... 0.         0.         0.        ]
# Item ID: 184, Similarity values: [0.96975445 0.95149904 0.95334282 ... 0.         0.         1.        ]
# Item ID: 185, Similarity values: [0.96471242 0.93403545 0.94248264 ... 0.         1.         0.        ]
# Item ID: 186, Similarity values: [0.96330704 0.94694003 0.96010358 ... 0.         1.         1.        ]
# Item ID: 187, Similarity values: [0.93800267 0.93238942 0.94454255 ... 0.         0.         0.        ]
# Item ID: 188, Similarity values: [0.94104629 0.92179742 0.92806199 ... 0.         0.         0.        ]
# Item ID: 189, Similarity values: [0.95672925 0.93069869 0.95100789 ... 1.         1.         1.        ]
# Item ID: 190, Similarity values: [0.9295438  0.90747906 0.91898723 ... 0.         0.         0.        ]
# Item ID: 191, Similarity values: [0.92872271 0.91320182 0.93417898 ... 0.         0.         0.        ]
# Item ID: 192, Similarity values: [0.95656908 0.93405433 0.91590153 ... 0.         0.         1.        ]
# Item ID: 193, Similarity values: [0.93746756 0.92493779 0.94865973 ... 1.         0.         0.        ]
# Item ID: 194, Similarity values: [0.97168007 0.95228563 0.94454072 ... 0.         0.         0.        ]
# Item ID: 195, Similarity values: [0.9550767  0.92358005 0.94622316 ... 0.         1.         0.        ]
# Item ID: 196, Similarity values: [0.94135321 0.91851869 0.92430741 ... 0.         0.         0.        ]
# Item ID: 197, Similarity values: [0.91722663 0.90994965 0.87845381 ... 0.         0.         0.        ]
# Item ID: 198, Similarity values: [0.95420114 0.90453184 0.9355227  ... 0.         1.         0.        ]
# Item ID: 199, Similarity values: [0.97773004 0.93427716 0.96304543 ... 0.         0.         0.        ]
# Item ID: 200, Similarity values: [0.95531572 0.91386218 0.95776925 ... 0.         1.         0.        ]
# Item ID: 201, Similarity values: [0.96735922 0.93920986 0.9467212  ... 0.         0.         0.        ]
# Item ID: 202, Similarity values: [0.92718486 0.91993428 0.92714872 ... 1.         0.         0.        ]
# Item ID: 266, Similarity values: [0.9620724  0.93884909 0.9693389  ... 0.         0.         0.        ]
# Item ID: 267, Similarity values: [0.94737687 0.92651173 0.93982357 ... 0.         0.         0.        ]
# Item ID: 268, Similarity values: [0.92328996 0.9068424  0.89933734 ... 0.         0.         0.        ]
# Item ID: 269, Similarity values: [0.94871638 0.95565503 0.9435589  ... 0.         0.         0.        ]
# Item ID: 270, Similarity values: [0.95942346 0.96494461 0.96217251 ... 0.         0.         0.        ]
# Item ID: 271, Similarity values: [0.95295485 0.93947155 0.95572757 ... 0.         0.         0.        ]
# Item ID: 272, Similarity values: [0.96897657 0.95168477 0.95061781 ... 0.         0.         0.        ]
# Item ID: 273, Similarity values: [0.96443901 0.9425479  0.95962203 ... 0.         0.         0.        ]
# Item ID: 274, Similarity values: [0.95083699 0.91672092 0.94798022 ... 1.         0.         1.        ]
# Item ID: 275, Similarity values: [0.96880716 0.9542099  0.95625036 ... 0.         0.         1.        ]
# Item ID: 276, Similarity values: [0.96915496 0.95441865 0.93048517 ... 1.         0.         1.        ]
# Item ID: 277, Similarity values: [0.95451604 0.94541077 0.94684416 ... 0.         1.         0.        ]
# Item ID: 278, Similarity values: [0.94058977 0.9391458  0.91994246 ... 0.         0.         0.        ]
# Item ID: 279, Similarity values: [0.96259641 0.964844   0.96309948 ... 0.         0.         0.        ]
# Item ID: 280, Similarity values: [0.96977237 0.94898207 0.9677118  ... 1.         0.         0.        ]
# Item ID: 281, Similarity values: [0.94327684 0.9219729  0.95210747 ... 0.         0.         0.        ]
# Item ID: 282, Similarity values: [0.9701222  0.94885311 0.97933619 ... 0.         0.         0.        ]
# Item ID: 283, Similarity values: [0.96004797 0.95670075 0.95640606 ... 0.         0.         0.        ]
# Item ID: 284, Similarity values: [0.96597827 0.95343759 0.9376874  ... 0.         0.         0.        ]
# Item ID: 285, Similarity values: [0.9568534  0.94988376 0.93756946 ... 0.         0.         0.        ]
# Item ID: 286, Similarity values: [0.95679328 0.9361395  0.92656694 ... 0.         0.         0.        ]
# Item ID: 287, Similarity values: [0.92976345 0.89979929 0.89545298 ... 0.         0.         0.        ]
# Item ID: 288, Similarity values: [0.95762576 0.94558232 0.93618104 ... 0.         0.         0.        ]
# Item ID: 289, Similarity values: [0.96849936 0.96145182 0.92132791 ... 0.         0.         0.        ]
# Item ID: 290, Similarity values: [0.95360656 0.93817566 0.93848099 ... 1.         0.         1.        ]
# Item ID: 291, Similarity values: [0.96508576 0.95685491 0.94477329 ... 0.         0.         0.        ]
# Item ID: 292, Similarity values: [0.96000571 0.94541311 0.95545704 ... 0.         1.         0.        ]
# Item ID: 293, Similarity values: [0.94097051 0.92055674 0.94666711 ... 0.         0.         0.        ]
# Item ID: 294, Similarity values: [0.94500881 0.92786218 0.90711941 ... 0.         0.         0.        ]
# Item ID: 295, Similarity values: [0.94676334 0.92020334 0.96915427 ... 0.         0.         0.        ]
# Item ID: 296, Similarity values: [0.94792823 0.94699216 0.93612401 ... 0.         0.         0.        ]
# Item ID: 391, Similarity values: [0.96225376 0.90946761 0.95634748 ... 0.         0.         0.        ]
# Item ID: 392, Similarity values: [0.96295627 0.9305603  0.9629183  ... 0.         0.         0.        ]
# Item ID: 393, Similarity values: [0.95792568 0.94776925 0.94508815 ... 0.         0.         0.        ]
# Item ID: 394, Similarity values: [0.97087504 0.94502361 0.95958025 ... 0.         0.         0.        ]
# Item ID: 395, Similarity values: [0.92739274 0.91764622 0.94180138 ... 0.         0.         0.        ]
# Item ID: 396, Similarity values: [0.94290807 0.91574677 0.96041055 ... 0.         0.         0.        ]
# Item ID: 397, Similarity values: [0.94157094 0.92130618 0.95139484 ... 0.         0.         0.        ]
# Item ID: 398, Similarity values: [0.91774493 0.93874002 0.92466251 ... 0.         0.         0.        ]
# Item ID: 399, Similarity values: [0.95531831 0.91406224 0.94022943 ... 0.         0.         0.        ]
# Item ID: 400, Similarity values: [0.94989392 0.93275061 0.95384069 ... 1.         0.         1.        ]
# Item ID: 401, Similarity values: [0.9162847  0.90789606 0.93789372 ... 0.         1.         0.        ]
# Item ID: 402, Similarity values: [0.91266692 0.90608262 0.92642816 ... 0.         0.         0.        ]
# Item ID: 403, Similarity values: [0.95413354 0.93181453 0.96804048 ... 0.         0.         0.        ]
# Item ID: 404, Similarity values: [0.94876598 0.92306041 0.95331311 ... 0.         0.         0.        ]
# Item ID: 405, Similarity values: [0.95963809 0.94971672 0.95921195 ... 0.         0.         0.        ]
# Item ID: 406, Similarity values: [0.94060755 0.91245602 0.9416104  ... 0.         0.         0.        ]
# Item ID: 407, Similarity values: [0.97644873 0.9465299  0.94295671 ... 0.         0.         0.        ]
# Item ID: 408, Similarity values: [0.92755452 0.91548662 0.95342246 ... 0.         1.         0.        ]
# Item ID: 409, Similarity values: [0.96358156 0.96958876 0.94984635 ... 0.         0.         0.        ]
# Item ID: 410, Similarity values: [0.90236855 0.91381155 0.94159844 ... 0.         0.         0.        ]
# Item ID: 411, Similarity values: [0.96585863 0.94624515 0.95987067 ... 0.         0.         0.        ]
# Item ID: 412, Similarity values: [0.96331076 0.94126288 0.96690265 ... 0.         0.         0.        ]
# Item ID: 413, Similarity values: [0.94636105 0.90942818 0.93843924 ... 0.         0.         0.        ]
# Item ID: 414, Similarity values: [0.96333217 0.93232552 0.97544293 ... 0.         0.         0.        ]
# Item ID: 415, Similarity values: [0.96618499 0.93442068 0.96482932 ... 0.         0.         0.        ]
# Item ID: 416, Similarity values: [0.95012914 0.92336482 0.94759397 ... 0.         0.         0.        ]
# Item ID: 417, Similarity values: [0.9663397  0.94814064 0.97328442 ... 0.         0.         0.        ]
# Item ID: 418, Similarity values: [0.96285348 0.95133549 0.96286376 ... 0.         0.         0.        ]
# Item ID: 419, Similarity values: [0.91601441 0.89785276 0.94644968 ... 0.         0.         0.        ]
# Item ID: 420, Similarity values: [0.97567782 0.94841182 0.97035087 ... 0.         0.         0.        ]
# Item ID: 421, Similarity values: [0.96801974 0.9494386  0.95618546 ... 0.         0.         0.        ]
# Item ID: 485, Similarity values: [0.88461958 0.8822988  0.92978481 ... 0.         0.         0.        ]
# Item ID: 486, Similarity values: [0.97687555 0.95481862 0.95677047 ... 0.         0.         0.        ]
# Item ID: 487, Similarity values: [0.9465511  0.9128336  0.94955023 ... 1.         0.         0.        ]
# Item ID: 488, Similarity values: [0.95775484 0.95887622 0.94698439 ... 1.         0.         0.        ]
# Item ID: 489, Similarity values: [0.93912819 0.92331199 0.93509595 ... 1.         0.         0.        ]
# Item ID: 490, Similarity values: [0.96707471 0.93140498 0.95621309 ... 0.         0.         0.        ]
# Item ID: 491, Similarity values: [0.97014199 0.95943206 0.95735237 ... 0.         0.         0.        ]
# Item ID: 492, Similarity values: [0.90912352 0.92574089 0.92531525 ... 0.         1.         0.        ]
# Item ID: 493, Similarity values: [0.93170507 0.93661706 0.89545009 ... 0.         0.         0.        ]
# Item ID: 494, Similarity values: [0.97608532 0.95833196 0.98442334 ... 0.         0.         0.        ]
# Item ID: 495, Similarity values: [0.96636442 0.95879811 0.94658469 ... 0.         0.         0.        ]
# Item ID: 496, Similarity values: [0.97551203 0.9458548  0.95938849 ... 0.         0.         0.        ]
# Item ID: 497, Similarity values: [0.96562291 0.95442632 0.96092981 ... 0.         0.         0.        ]
# Item ID: 498, Similarity values: [0.95103352 0.95433022 0.94350566 ... 0.         0.         0.        ]
# Item ID: 499, Similarity values: [0.96511369 0.95547593 0.95578567 ... 0.         0.         1.        ]
# Item ID: 500, Similarity values: [0.97154125 0.96024025 0.96301459 ... 0.         0.         0.        ]
# Item ID: 501, Similarity values: [0.93745662 0.94541782 0.94738506 ... 0.         0.         0.        ]
# Item ID: 502, Similarity values: [0.95877877 0.94738149 0.95576067 ... 0.         0.         0.        ]
# Item ID: 503, Similarity values: [0.95494351 0.91670487 0.95214142 ... 0.         0.         0.        ]
# Item ID: 504, Similarity values: [0.96190676 0.93734636 0.94511301 ... 1.         0.         0.        ]
# Item ID: 505, Similarity values: [0.9721314  0.94014582 0.96454535 ... 0.         0.         1.        ]
# Item ID: 506, Similarity values: [0.97227076 0.96105158 0.96365448 ... 0.         0.         0.        ]
# Item ID: 507, Similarity values: [0.96660757 0.95008627 0.94912745 ... 0.         0.         0.        ]
# Item ID: 508, Similarity values: [0.93051783 0.91656326 0.91978199 ... 0.         0.         0.        ]
# Item ID: 509, Similarity values: [0.96335509 0.93690152 0.94344826 ... 1.         0.         0.        ]
# Item ID: 510, Similarity values: [0.96198309 0.95142151 0.96644932 ... 0.         0.         0.        ]
# Item ID: 511, Similarity values: [0.94160376 0.91955076 0.93904002 ... 1.         0.         0.        ]
# Item ID: 512, Similarity values: [0.93964366 0.92347193 0.91675141 ... 1.         0.         1.        ]
# Item ID: 513, Similarity values: [0.93547331 0.90610484 0.94691888 ... 0.         0.         0.        ]
# Item ID: 514, Similarity values: [0.94612236 0.92744964 0.94752395 ... 1.         0.         0.        ]
# Item ID: 515, Similarity values: [0.96161528 0.94469093 0.9433236  ... 0.         0.         0.        ]
# Item ID: 516, Similarity values: [0.96135502 0.94653825 0.94249528 ... 0.         0.         0.        ]
# Item ID: 517, Similarity values: [0.9480893  0.94564735 0.93222714 ... 0.         0.         1.        ]
# Item ID: 518, Similarity values: [0.94952964 0.9374047  0.96477316 ... 0.         0.         0.        ]
# Item ID: 519, Similarity values: [0.95487165 0.94331901 0.95615631 ... 0.         0.         0.        ]
# Item ID: 520, Similarity values: [0.96674133 0.94927078 0.96511738 ... 0.         0.         0.        ]
# Item ID: 521, Similarity values: [0.95155123 0.91965888 0.9371943  ... 1.         0.         1.        ]
# Item ID: 522, Similarity values: [0.94849885 0.94379163 0.95787318 ... 0.         0.         0.        ]
# Item ID: 523, Similarity values: [0.9680699 0.9470621 0.9583161 ... 1.        0.        0.       ]
# Item ID: 524, Similarity values: [0.9616686  0.95469992 0.94958805 ... 0.         0.         0.        ]
# Item ID: 525, Similarity values: [0.97255807 0.95604886 0.97150009 ... 0.         0.         0.        ]
# Item ID: 526, Similarity values: [0.93123743 0.93701293 0.9550267  ... 0.         0.         0.        ]
# Item ID: 527, Similarity values: [0.96619399 0.95268242 0.95656581 ... 0.         0.         1.        ]
# Item ID: 528, Similarity values: [0.95403016 0.93100643 0.956211   ... 0.         1.         0.        ]
# Item ID: 529, Similarity values: [0.97817874 0.95236636 0.96464424 ... 1.         0.         0.        ]
# Item ID: 530, Similarity values: [0.96735144 0.95267145 0.96676503 ... 0.         0.         0.        ]
# Item ID: 531, Similarity values: [0.95757371 0.95447879 0.95823708 ... 0.         0.         1.        ]
# Item ID: 532, Similarity values: [0.91334566 0.89205144 0.8841641  ... 0.         0.         0.        ]
# Item ID: 533, Similarity values: [0.94884327 0.93996779 0.95530459 ... 0.         0.         0.        ]
# Item ID: 534, Similarity values: [0.96017193 0.94116728 0.96834218 ... 1.         0.         0.        ]
# Item ID: 535, Similarity values: [0.9743906  0.9578736  0.97135487 ... 0.         0.         1.        ]
# Item ID: 536, Similarity values: [0.96592293 0.94539424 0.95680232 ... 0.         0.         0.        ]
# Item ID: 537, Similarity values: [0.9582216  0.94001689 0.94750332 ... 0.         0.         1.        ]
# Item ID: 538, Similarity values: [0.9510065  0.92948156 0.95320608 ... 1.         0.         0.        ]
# Item ID: 539, Similarity values: [0.98029463 0.96416263 0.97122212 ... 0.         0.         1.        ]
# Item ID: 540, Similarity values: [0.9772784  0.97878943 0.98198738 ... 0.         0.         0.        ]
# Item ID: 541, Similarity values: [0.92307016 0.91473618 0.92536087 ... 0.         0.         0.        ]
# Item ID: 542, Similarity values: [0.96554663 0.94223144 0.95599539 ... 0.         0.         0.        ]
# Item ID: 543, Similarity values: [0.9482914  0.91292856 0.97421031 ... 0.         0.         0.        ]
# Item ID: 544, Similarity values: [0.87516484 0.88777273 0.90516753 ... 0.         0.         0.        ]
# Item ID: 545, Similarity values: [0.95746489 0.95166146 0.95989893 ... 0.         0.         0.        ]
# Item ID: 546, Similarity values: [0.97544846 0.95417654 0.9682333  ... 0.         0.         0.        ]
# Item ID: 547, Similarity values: [0.96640116 0.93636934 0.97014546 ... 0.         0.         0.        ]
# Item ID: 548, Similarity values: [0.93771067 0.94660335 0.95249905 ... 0.         0.         0.        ]
# Item ID: 549, Similarity values: [0.94858968 0.90018469 0.89527379 ... 0.         0.         0.        ]
# Item ID: 550, Similarity values: [0.96532771 0.9573192  0.95349515 ... 1.         0.         0.        ]
# Item ID: 551, Similarity values: [0.94725921 0.9536966  0.95640101 ... 0.         0.         0.        ]
# Item ID: 552, Similarity values: [0.95170988 0.94638949 0.94810378 ... 0.         0.         0.        ]
# Item ID: 553, Similarity values: [0.9754478  0.95533146 0.96902304 ... 0.         0.         0.        ]
# Item ID: 554, Similarity values: [0.93205836 0.95150903 0.9405425  ... 0.         0.         0.        ]
# Item ID: 555, Similarity values: [0.93514067 0.9177927  0.93202859 ... 1.         0.         0.        ]
# Item ID: 556, Similarity values: [0.95032725 0.92921813 0.94533558 ... 0.         0.         0.        ]
# Item ID: 557, Similarity values: [0.95028085 0.93596307 0.95694991 ... 0.         0.         0.        ]
# Item ID: 558, Similarity values: [0.94388296 0.92687644 0.95717349 ... 0.         0.         0.        ]
# Item ID: 559, Similarity values: [0.97469985 0.95530717 0.95490095 ... 0.         0.         0.        ]
# Item ID: 560, Similarity values: [0.97778294 0.94962749 0.96355512 ... 0.         0.         0.        ]
# Item ID: 561, Similarity values: [0.9404077  0.93135487 0.94232324 ... 0.         0.         0.        ]
# Item ID: 562, Similarity values: [0.97203034 0.94303547 0.95574901 ... 0.         0.         0.        ]
# Item ID: 563, Similarity values: [0.95944402 0.94246072 0.9598626  ... 0.         0.         0.        ]
# Item ID: 564, Similarity values: [0.90538605 0.90446303 0.91019926 ... 0.         0.         0.        ]
# Item ID: 565, Similarity values: [0.96976993 0.94907464 0.96099894 ... 0.         0.         1.        ]
# Item ID: 566, Similarity values: [0.92546102 0.91112325 0.93628705 ... 0.         0.         0.        ]
# Item ID: 567, Similarity values: [0.9365334  0.91685383 0.95173993 ... 0.         0.         0.        ]
# Item ID: 568, Similarity values: [0.9097247  0.9043616  0.92501392 ... 0.         0.         0.        ]
# Item ID: 569, Similarity values: [0.8788467  0.84832706 0.91790947 ... 0.         0.         0.        ]
# Item ID: 570, Similarity values: [0.96713171 0.93381675 0.96386641 ... 0.         0.         0.        ]
# Item ID: 571, Similarity values: [0.94985758 0.92268337 0.94943548 ... 0.         0.         0.        ]
# Item ID: 572, Similarity values: [0.9135984  0.95174739 0.92593732 ... 0.         0.         0.        ]
# Item ID: 573, Similarity values: [0.94498878 0.93298271 0.94226587 ... 0.         0.         1.        ]
# Item ID: 574, Similarity values: [0.8518643  0.8737101  0.91714496 ... 0.         0.         0.        ]
# Item ID: 575, Similarity values: [0.9123217  0.88807636 0.92758673 ... 0.         0.         0.        ]
# Item ID: 576, Similarity values: [0.952237   0.92495751 0.95571256 ... 0.         0.         0.        ]
# Item ID: 577, Similarity values: [0.93753398 0.93984829 0.94667027 ... 0.         1.         1.        ]
# Item ID: 578, Similarity values: [0.94707315 0.91110536 0.95240944 ... 0.         0.         0.        ]
# Item ID: 579, Similarity values: [0.93596638 0.93432342 0.94725864 ... 0.         0.         0.        ]
# Item ID: 580, Similarity values: [0.96901242 0.94151653 0.96766827 ... 0.         0.         0.        ]
# Item ID: 581, Similarity values: [0.96307101 0.90631044 0.95150545 ... 0.         1.         0.        ]
# Item ID: 582, Similarity values: [0.97121475 0.95104965 0.95760673 ... 0.         0.         0.        ]
# Item ID: 583, Similarity values: [0.94877806 0.90701068 0.94740958 ... 0.         0.         0.        ]
# Item ID: 584, Similarity values: [0.94405578 0.93119005 0.9322908  ... 1.         0.         0.        ]
# Item ID: 585, Similarity values: [0.97116871 0.94822025 0.97368869 ... 0.         1.         0.        ]
# ...
# Item ID: 3493, Similarity values: [0.89087081 1.         1.         ... 0.         0.         0.        ]
# Item ID: 3494, Similarity values: [0.94371655 1.         0.         ... 0.         0.         0.        ]
# Item ID: 3495, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3496, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3497, Similarity values: [0.98386991 0.         0.         ... 0.         0.         0.        ]
# Item ID: 3498, Similarity values: [0.98994949 1.         0.98994949 ... 0.         0.         0.        ]
# Item ID: 3499, Similarity values: [0.90373784 1.         1.         ... 0.         0.         0.        ]
# Item ID: 3500, Similarity values: [0.95667388 0.         0.         ... 0.         0.         0.        ]
# Item ID: 3501, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3502, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3503, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3504, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3505, Similarity values: [0.97149379 1.         0.         ... 0.         0.         0.        ]
# Item ID: 3506, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3507, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3508, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3509, Similarity values: [0.99705449 1.         1.         ... 0.         0.         0.        ]
# Item ID: 3510, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3511, Similarity values: [0.85726114 1.         0.86164044 ... 0.         0.         0.        ]
# Item ID: 3512, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3513, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3514, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3515, Similarity values: [0.92163538 1.         0.         ... 0.         0.         0.        ]
# Item ID: 3516, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3517, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3518, Similarity values: [1. 1. 0. ... 0. 0. 0.]
# Item ID: 3519, Similarity values: [0.98994949 1.         0.         ... 0.         0.         0.        ]
# Item ID: 3520, Similarity values: [1. 0. 1. ... 0. 0. 0.]
# Item ID: 3521, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3522, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3523, Similarity values: [0.9701425 1.        1.        ... 0.        0.        0.       ]
# Item ID: 3524, Similarity values: [0.84366149 1.         1.         ... 0.         0.         0.        ]
# Item ID: 3525, Similarity values: [0.99886814 1.         1.         ... 0.         0.         0.        ]
# Item ID: 3526, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3527, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3528, Similarity values: [0.92163538 1.         1.         ... 0.         0.         0.        ]
# Item ID: 3529, Similarity values: [0.98836937 1.         0.         ... 0.         0.         0.        ]
# Item ID: 3530, Similarity values: [0.9258201 0.9486833 1.        ... 0.        0.        0.       ]
# Item ID: 3531, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3532, Similarity values: [0.97124771 1.         0.         ... 0.         0.         0.        ]
# Item ID: 3533, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3534, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3535, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3536, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3537, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3538, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3539, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3540, Similarity values: [0.95852253 1.         1.         ... 0.         0.         0.        ]
# Item ID: 3541, Similarity values: [0.99151403 0.96       0.95726884 ... 0.         0.         0.        ]
# Item ID: 3542, Similarity values: [1.         0.98994949 1.         ... 0.         0.         0.        ]
# Item ID: 3543, Similarity values: [1. 1. 0. ... 0. 0. 0.]
# Item ID: 3544, Similarity values: [0.95530392 0.96225045 0.95096343 ... 0.         0.         0.        ]
# Item ID: 3545, Similarity values: [0. 0. 1. ... 0. 0. 0.]
# Item ID: 3546, Similarity values: [1. 0. 1. ... 0. 0. 0.]
# Item ID: 3547, Similarity values: [0. 0. 0. ... 0. 0. 0.]
# Item ID: 3548, Similarity values: [0.9486833 0.        0.        ... 0.        0.        0.       ]
# Item ID: 3549, Similarity values: [0.88640526 0.         1.         ... 0.         0.         0.        ]
# Item ID: 3550, Similarity values: [1. 0. 1. ... 0. 0. 0.]
# Item ID: 3551, Similarity values: [0.95560832 1.         0.93124039 ... 0.         0.         0.        ]
# Item ID: 3552, Similarity values: [0.96291111 0.99004368 0.89085531 ... 0.         0.         0.        ]
# Item ID: 3553, Similarity values: [0.93       0.98058068 0.87854445 ... 0.         0.         0.        ]
# Item ID: 3554, Similarity values: [0.9873461 1.        1.        ... 0.        0.        0.       ]
# Item ID: 3555, Similarity values: [0. 0. 0. ... 0. 0. 0.]
# Item ID: 3556, Similarity values: [0. 0. 0. ... 0. 0. 0.]
# Item ID: 3557, Similarity values: [0.94186047 1.         0.96750317 ... 0.         0.         0.        ]
# Item ID: 3558, Similarity values: [0.99388373 1.         0.         ... 0.         0.         0.        ]
# Item ID: 3559, Similarity values: [1. 0. 1. ... 0. 0. 0.]
# Item ID: 3560, Similarity values: [0.8819171  1.         0.89442719 ... 0.         0.         0.        ]
# Item ID: 3561, Similarity values: [0.99422059 1.         0.96827732 ... 0.         0.         0.        ]
# Item ID: 3562, Similarity values: [1. 0. 1. ... 0. 0. 0.]
# Item ID: 3563, Similarity values: [0.96561576 1.         0.98386991 ... 0.         0.         0.        ]
# Item ID: 3564, Similarity values: [1. 0. 1. ... 0. 0. 0.]
# Item ID: 3565, Similarity values: [0. 0. 1. ... 0. 0. 0.]
# Item ID: 3566, Similarity values: [0.9876754  1.         0.98994949 ... 0.         0.         0.        ]
# Item ID: 3567, Similarity values: [0. 0. 0. ... 0. 0. 0.]
# Item ID: 3568, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3569, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3570, Similarity values: [0. 0. 0. ... 0. 0. 0.]
# Item ID: 3571, Similarity values: [1.         1.         0.99388373 ... 0.         0.         0.        ]
# Item ID: 3572, Similarity values: [0. 0. 1. ... 0. 0. 0.]
# Item ID: 3573, Similarity values: [0.86904819 1.         0.         ... 0.         0.         0.        ]
# Item ID: 3574, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3575, Similarity values: [0.98685889 0.97689623 0.98058068 ... 0.         0.         0.        ]
# Item ID: 3576, Similarity values: [1. 0. 1. ... 0. 0. 0.]
# Item ID: 3577, Similarity values: [0. 0. 0. ... 0. 0. 0.]
# Item ID: 3578, Similarity values: [0.96814116 0.93704257 0.8382063  ... 0.         0.         0.        ]
# Item ID: 3579, Similarity values: [0.98994949 1.         0.         ... 1.         0.         0.        ]
# Item ID: 3580, Similarity values: [0.94       0.96827732 0.99388373 ... 0.         0.         0.        ]
# Item ID: 3581, Similarity values: [0.97590007 0.86181282 0.99453584 ... 0.         0.         0.        ]
# Item ID: 3582, Similarity values: [1.         0.91914503 1.         ... 0.         0.         0.        ]
# Item ID: 3583, Similarity values: [1. 1. 0. ... 0. 0. 0.]
# Item ID: 3584, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3585, Similarity values: [0. 0. 0. ... 0. 0. 0.]
# Item ID: 3586, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3587, Similarity values: [1. 1. 1. ... 0. 0. 0.]
# Item ID: 3588, Similarity values: [1.         1.         0.99587059 ... 0.         0.         0.        ]
# Item ID: 3589, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3590, Similarity values: [0. 0. 0. ... 0. 0. 0.]
# Item ID: 3591, Similarity values: [0. 0. 0. ... 0. 0. 0.]
# Item ID: 3592, Similarity values: [0.97676833 0.99951208 0.99439606 ... 1.         0.         0.        ]
# Item ID: 3593, Similarity values: [0.9701425 1.        1.        ... 0.        0.        0.       ]
# Item ID: 3594, Similarity values: [0.9701425 1.        1.        ... 0.        0.        0.       ]
# Item ID: 3595, Similarity values: [0.85280287 1.         0.90267093 ... 0.         0.         0.        ]
# Item ID: 3596, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3597, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3598, Similarity values: [0.9486833  1.         0.90906482 ... 0.         0.         0.        ]
# Item ID: 3599, Similarity values: [0. 0. 0. ... 0. 0. 0.]
# Item ID: 3600, Similarity values: [0. 0. 0. ... 0. 0. 0.]
# Item ID: 3601, Similarity values: [0. 0. 0. ... 0. 0. 0.]
# Item ID: 3602, Similarity values: [0. 0. 0. ... 0. 0. 0.]
# Item ID: 3603, Similarity values: [0.92329856 0.79543172 0.         ... 0.         0.         0.        ]
# Item ID: 3604, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3605, Similarity values: [0.97676833 1.         0.97843575 ... 0.         0.         0.        ]
# Item ID: 3606, Similarity values: [0.9918366 1.        1.        ... 0.        0.        0.       ]
# Item ID: 3607, Similarity values: [0.90430759 1.         0.99388373 ... 0.         0.         0.        ]
# Item ID: 3608, Similarity values: [0. 1. 1. ... 0. 0. 0.]
# Item ID: 3609, Similarity values: [0. 0. 0. ... 0. 0. 0.]
# Item ID: 3610, Similarity values: [0. 0. 0. ... 0. 0. 0.]
# Item ID: 3611, Similarity values: [0.84084099 0.         0.776114   ... 0.         0.         0.        ]
# Item ID: 3612, Similarity values: [1.         0.         0.93742527 ... 0.         0.         0.        ]
# Item ID: 3613, Similarity values: [0.95560832 0.9918366  1.         ... 0.         0.         0.        ]
# Item ID: 3614, Similarity values: [0. 0. 1. ... 0. 0. 0.]
# Item ID: 3615, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3616, Similarity values: [0. 1. 1. ... 0. 0. 0.]
# Item ID: 3617, Similarity values: [0.9486833 1.        1.        ... 0.        0.        0.       ]
# Item ID: 3618, Similarity values: [0.96827732 1.         1.         ... 0.         0.         0.        ]
# Item ID: 3619, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3620, Similarity values: [0. 0. 0. ... 0. 0. 0.]
# Item ID: 3621, Similarity values: [1. 0. 1. ... 0. 0. 0.]
# Item ID: 3622, Similarity values: [1. 0. 1. ... 0. 0. 0.]
# Item ID: 3623, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3624, Similarity values: [1. 0. 1. ... 0. 0. 0.]
# Item ID: 3625, Similarity values: [0.99388373 0.         1.         ... 0.         0.         0.        ]
# Item ID: 3626, Similarity values: [1. 0. 1. ... 0. 0. 0.]
# Item ID: 3627, Similarity values: [0. 0. 1. ... 0. 0. 0.]
# Item ID: 3628, Similarity values: [0.94588894 0.98994949 0.99388373 ... 0.         0.         0.        ]
# Item ID: 3629, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3630, Similarity values: [1. 0. 1. ... 0. 0. 0.]
# Item ID: 3631, Similarity values: [1. 0. 1. ... 0. 0. 0.]
# Item ID: 3632, Similarity values: [0. 1. 0. ... 0. 0. 0.]
# Item ID: 3633, Similarity values: [1. 1. 0. ... 0. 0. 0.]
# Item ID: 3634, Similarity values: [1.         0.99227788 0.         ... 0.         0.         0.        ]
# Item ID: 3635, Similarity values: [1. 1. 0. ... 0. 0. 0.]
# Item ID: 3636, Similarity values: [1. 0. 1. ... 0. 0. 0.]
# Item ID: 3637, Similarity values: [0. 0. 0. ... 0. 0. 0.]
# Item ID: 3638, Similarity values: [1. 0. 1. ... 0. 0. 0.]
# Item ID: 3639, Similarity values: [0. 0. 1. ... 0. 0. 0.]
# Item ID: 3640, Similarity values: [0. 0. 1. ... 0. 0. 0.]
# Item ID: 3641, Similarity values: [0. 0. 1. ... 0. 0. 0.]
# Item ID: 3642, Similarity values: [0. 0. 1. ... 0. 0. 0.]
# Item ID: 3643, Similarity values: [0. 0. 1. ... 0. 0. 0.]
# Item ID: 3644, Similarity values: [1. 0. 1. ... 0. 0. 0.]
# Item ID: 3645, Similarity values: [0. 0. 0. ... 0. 0. 0.]
# Item ID: 3646, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3647, Similarity values: [0. 1. 0. ... 0. 0. 0.]
# Item ID: 3648, Similarity values: [0. 0. 0. ... 0. 0. 0.]
# Item ID: 3649, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3650, Similarity values: [0. 0. 0. ... 0. 0. 0.]
# Item ID: 3651, Similarity values: [0.98994949 1.         0.99951208 ... 0.         0.         0.        ]
# Item ID: 3652, Similarity values: [0. 0. 0. ... 0. 0. 0.]
# Item ID: 3653, Similarity values: [0. 0. 0. ... 0. 0. 0.]
# Item ID: 3654, Similarity values: [0. 0. 0. ... 0. 0. 0.]
# Item ID: 3655, Similarity values: [1. 1. 1. ... 0. 0. 0.]
# Item ID: 3656, Similarity values: [1. 1. 1. ... 0. 0. 0.]
# Item ID: 3657, Similarity values: [1. 1. 1. ... 0. 0. 0.]
# Item ID: 3658, Similarity values: [1. 1. 1. ... 0. 0. 0.]
# Item ID: 3659, Similarity values: [1. 1. 1. ... 0. 0. 0.]
# Item ID: 3660, Similarity values: [1. 1. 1. ... 0. 0. 0.]
# Item ID: 3661, Similarity values: [1. 1. 1. ... 0. 0. 0.]
# Item ID: 3662, Similarity values: [1. 1. 1. ... 0. 0. 0.]
# Item ID: 3663, Similarity values: [1. 1. 1. ... 0. 0. 0.]
# Item ID: 3664, Similarity values: [0.95843185 1.         0.99388373 ... 0.         0.         0.        ]
# Item ID: 3665, Similarity values: [1. 1. 1. ... 0. 0. 0.]
# Item ID: 3666, Similarity values: [0.85749293 1.         1.         ... 0.         0.         0.        ]
# Item ID: 3667, Similarity values: [1. 1. 1. ... 0. 0. 0.]
# Item ID: 3668, Similarity values: [0.99388373 1.         1.         ... 0.         0.         0.        ]
# Item ID: 3669, Similarity values: [1. 0. 1. ... 0. 0. 0.]
# Item ID: 3670, Similarity values: [0.9701425  1.         0.91914503 ... 0.         0.         0.        ]
# Item ID: 3671, Similarity values: [1. 0. 1. ... 0. 0. 0.]
# Item ID: 3672, Similarity values: [0.83205029 0.         0.         ... 0.         0.         0.        ]
# Item ID: 3673, Similarity values: [0. 0. 0. ... 0. 0. 0.]
# Item ID: 3674, Similarity values: [0. 0. 0. ... 0. 0. 0.]
# Item ID: 3675, Similarity values: [0. 0. 0. ... 0. 0. 0.]
# Item ID: 3676, Similarity values: [0. 0. 0. ... 0. 0. 0.]
# Item ID: 3677, Similarity values: [0. 0. 1. ... 0. 0. 0.]
# Item ID: 3678, Similarity values: [0. 0. 0. ... 0. 0. 0.]
# Item ID: 3679, Similarity values: [1. 0. 1. ... 0. 0. 0.]
# Item ID: 3680, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3681, Similarity values: [0. 0. 0. ... 0. 0. 0.]
# Item ID: 3682, Similarity values: [0. 1. 0. ... 0. 0. 0.]
# Item ID: 3683, Similarity values: [0. 1. 0. ... 0. 0. 0.]
# Item ID: 3684, Similarity values: [0. 0. 0. ... 0. 0. 0.]
# Item ID: 3685, Similarity values: [1. 0. 1. ... 0. 0. 0.]
# Item ID: 3686, Similarity values: [0. 0. 0. ... 0. 0. 0.]
# Item ID: 3687, Similarity values: [0. 0. 0. ... 0. 0. 0.]
# Item ID: 3688, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3689, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3690, Similarity values: [0.99469179 1.         0.         ... 0.         0.         0.        ]
# Item ID: 3691, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3692, Similarity values: [1. 1. 1. ... 0. 0. 0.]
# Item ID: 3693, Similarity values: [0. 0. 0. ... 0. 0. 0.]
# Item ID: 3694, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3695, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3696, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3697, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3698, Similarity values: [0. 1. 1. ... 0. 0. 0.]
# Item ID: 3699, Similarity values: [1. 1. 0. ... 0. 0. 0.]
# Item ID: 3700, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3701, Similarity values: [0.99099243 1.         1.         ... 0.         0.         0.        ]
# Item ID: 3702, Similarity values: [1. 0. 0. ... 0. 0. 0.]
# Item ID: 3703, Similarity values: [0. 0. 0. ... 1. 0. 0.]
# Item ID: 3704, Similarity values: [1. 0. 0. ... 0. 1. 0.]
# Item ID: 3705, Similarity values: [0. 0. 0. ... 0. 0. 1.]
# 基于物品的协同过滤为用户 1 推荐的电影（电影ID，预测评分）：
# 电影ID: 1, 预测评分: 3.581564453029317
# 电影ID: 2, 预测评分: 3.581564453029317
# 电影ID: 3, 预测评分: 3.581564453029317
# 电影ID: 4, 预测评分: 3.581564453029317
# 电影ID: 5, 预测评分: 3.581564453029317
# 电影ID: 6, 预测评分: 3.581564453029317
# 电影ID: 7, 预测评分: 3.581564453029317
# 电影ID: 8, 预测评分: 3.581564453029317
# 电影ID: 9, 预测评分: 3.581564453029317
# 电影ID: 10, 预测评分: 3.581564453029317
# 基于物品的协同过滤最佳参数计算耗时: 8431.611829996109 秒
